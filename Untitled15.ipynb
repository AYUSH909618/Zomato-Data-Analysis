# %%
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt
# Out:
# Matplotlib is building the font cache; this may take a moment.

# %%
pd.set_option('display.max_rows', None)
pd.set_option('display.max_columns', None)
df
# Out:
#                                                 name online_order book_table  \
# 0                                              Jalsa          Yes        Yes
# 1                                     Spice Elephant          Yes         No
# 2                                    San Churro Cafe          Yes         No
# 3                              Addhuri Udupi Bhojana           No         No
# 4                                      Grand Village           No         No
# 5                                    Timepass Dinner          Yes         No
# 6    Rosewood International Hotel - Bar & Restaurant           No         No
# 7                                             Onesta          Yes        Yes
# 8                                     Penthouse Cafe          Yes         No
# 9                                          Smacznego          Yes         No
# 10                                      Village Café          Yes         No
# ...

# %%
df[ 'rate' ] = df['rate' ].apply (lambda x : str(x).split('/')[0]) 
df[ 'rate' ] = pd.to_numeric(df['rate' ] , errors = 'coerce' )
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 148 entries, 0 to 147
# Data columns (total 7 columns):
#  #   Column                       Non-Null Count  Dtype
# ---  ------                       --------------  -----
#  0   name                         148 non-null    object
#  1   online_order                 148 non-null    object
#  2   book_table                   148 non-null    object
#  3   rate                         148 non-null    float64
#  4   votes                        148 non-null    int64
#  5   approx_cost(for two people)  148 non-null    int64
#  6   listed_in(type)              148 non-null    object
# dtypes: float64(1), int64(2), object(4)
# memory usage: 8.2+ KB

# %%
print("Average Rating:" , df['rate' ].mean()) 
print("Average cost for two: " , df['approx_cost(for two people)'].mean()) 
print("Total Restaurant : " , df.shape[0])
# Out:
# Average Rating: 3.6331081081081082
# Average cost for two:  418.2432432432432
# Total Restaurant :  148

# %%
sns.barplot(x ='online_order',y='rate',data = df,edgecolor='black',linewidth=1.5)
plt.title("Restaurant with online order option " )
plt.xlabel("Online order Availability " , fontsize=12)
plt.ylabel("Average Rating " , fontsize=12)
plt.show()

# %%
sns.countplot(x = 'online_order' , data = df)
plt.title("🪑Restaurant with Table Booking option ")
plt.show()

# %%
sns.barplot(x ='online_order' , y='rate' ,data=df)
plt.title(" Average Rating  : Online vs Offline order ")
plt.show()

# %%
sns.scatterplot(x='approx_cost(for two people)' , y= 'rate' , data=df)
plt.title("Cost vs Rating")
plt.show()

# %%
plt.figure(figsize=(8,4))
sns.countplot(x='Listed_in(type)' , data = df)
plt.title("Number of Restaurant by Type ")
plt.xticks(rotation=45)
plt.show()
